# %%
import os
print(os.getcwd())
# Out:
# C:\Users\patel\OneDrive\Desktop\Dashboard_portfolio\notebooks

# %%
price_data = pd.read_csv("../data/price_data.csv", parse_dates=["Date"], index_col="Date")

# %%
from pypfopt import EfficientFrontier

# Create a fresh EfficientFrontier instance for plotting
ef_plot = EfficientFrontier(mu, S)

fig, ax = plt.subplots(figsize=(8, 6))
plotting.plot_efficient_frontier(ef_plot, ax=ax, show_assets=True)

plt.title("Efficient Frontier")
plt.grid(True)
plt.show()
